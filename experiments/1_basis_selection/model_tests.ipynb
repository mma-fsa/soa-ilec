# %%
import pandas as pd
from pathlib import Path
import sys

sys.path.insert(0, str(Path.cwd().parent))  # adds parent directory
from experiments_lib import prompt_ilec_data, set_context_window_size, get_context_window, set_base_instructions, get_base_instructions

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Actuarial Intern
#
# The intern's manager has described the following task:
#
# >We'd like to select an appropriate expected basis for each insurance plan type. We expect that the basis will vary by issue year, but are open to other ideas.  Which of the bases would provide the best fit, if we are looking at the actual-to-expected ratio on an amount basis? The following expected bases are available:
#
# * Expected_Death_QX7580E_by_Amount
# * Expected_Death_QX2001VBT_by_Amount
# * Expected_Death_QX2008VBT_by_Amount
# * Expected_Death_QX2008VBTLU_by_Amount
# * Expected_Death_QX2015VBT_by_Amount
# * Expected_Death_QX7580E_by_Policy
# * Expected_Death_QX2001VBT_by_Policy
# * Expected_Death_QX2008VBT_by_Policy
# * Expected_Death_QX2008VBTLU_by_Policy
# * Expected_Death_QX2015VBT_by_Policy
# * ExpDeathQx2015VBTwMI_byPol
# * ExpDeathQx2015VBTwMI_byAmt
#
# This exercise will assume the intern has very little knowledge of the mechanics of life insurance (mortality improvement, preferred classes, etc.), and the final analysis produced by the intern will reflect that.

# %% [markdown]
# ## Setup LLM params
#
# These are used by the LLM to manage history, the context window includes the last N questions (from the user) and answers (from the agent / LLM)

# %%
set_context_window_size(10)

# %% [markdown]
# ## Canary

# %%
print(prompt_ilec_data("How many differerent insurance plan types are there, list them", model="gpt-5"))
# Out:
# Running request...
# There is 1 distinct insurance plan type in the data:
# - perm_historical

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Model #1

# %%
modeling_prompt = """The goal is to create a model to predict late-duration whole life (perm_historical) mortality on the ILEC_DATA. Use Number_Of_Deaths as the target (y_var) and Expected_Death_QX2015VBT_by_Policy as the offset (offset_var)"""\
    """The ILEC_DATA can be queried with sql_query() and its schema is available with sql_schema(), perform exploratory data analysis with these methods."""\
    """The ILEC_DATA has data quality problems, so identify and fix when possible. Remove any rows where Expected_Death_QX2015VBT_by_Policy <= 0."""\
    """To build a model, first call cmd_init(), this returns a session_id that should be passed as the first argument to the next cmd_*() call."""\
    """Each call to a cmd_*() method returns a session_id, which is an immutable workspace associated with any changes in state resulting from that method call, e.g. creation of datasets, models, and inference data."""\
    """This allows backtracking to previous states in modeling."""\
    """After calling cmd_init(), create two datasets called "perm_data_train" and "perm_data_test" with calls to cmd_create_dataset(), apply fixes for any data quality problems."""\
    """Next, determine variable importance call(s) to cmd_rpart(), use both actuarial soundness and predictive power as criteria for selecting variables."""\
    """Then, call cmd_glmnet() to build a model, any splines specified in design_matrix_vars must have both `Boundary.knots` and `knots` fully specified, do not use the `df` argument."""\
    """Use the decision tree returned by cmd_glmnet() to refine the design matrix, particularly inner knot locations."""\
    """Then run inference using cmd_run_inference() on both perm_data_train and perm_data_test to create perm_data_*_preds.  Run a decision tree on the results using cmd_rpart() and evaluate the final results."""\
    """Back-track if necessary.  Provide a final summary with a short description of the model rationale, any data quality problems and adjustments, and the session_id associated with the final step in the modeling process."""


print(prompt_ilec_data(modeling_prompt))
# Out:
# Running request...
# Plan
# - Target: Number_Of_Deaths
# - Offset: Expected_Death_QX2015VBT_by_Policy (column expdeathqx2015vbtwmi_bypol)
# - Scope: dataset = perm_historical, split by train_test
# - Remove rows where offset <= 0
# - Fix data quality: use attained_age_m = round(issue_age + duration) to standardize age across ALB/ANB and minor rounding inconsistencies.
#
# Key EDA findings
# - Rows: 2,701,318 perm_historical (TRAIN 1,901,686; TEST 799,632)
# - Offsets: no rows with expdeath<=0; min 1.69e-7, max 27.57
# - Ages/duration:
#   - issue_age: [0, 98]; attained_age: [4, 113]; duration: [5, 38]
#   - Quantiles: issue_age p25/50/75 = 25/39/54; attained_age p25/50/75 = 46/60/75; duration p25/50/75 = 17/22/27
#   - 25,400 rows with attained_age < duration (age basis/rounding artifact). We standardized to attained_age_m = round(issue_age + duration)
# - Categories: gender {MALE,FEMALE}; smoker_status {NONSMOKER,SMOKER}; age_basis {ANB,ALB}; face_amount_band_int 1..11; preferred_class mostly “NA”; preferred_indicator is numeric.
# - Early variable screening (Poisson rpart with offset=VBT expected):
#   - Strongest: face_amount_band_int, attained_age_m
#   - Secondary: duration, age_basis, observation_year, preferred_indicator
#   - Minor but sensible: gender, smoker_status
#
# Modeling steps and tool calls
# 1) Initialize
# - cmd_init() -> session_id = 22f76de9-f93f-40e1-b1bf-965a6e40560c
#
# 2) Create datasets (with filters/fixes)
# - TRAIN
#   - cmd_create_dataset(dataset_name = perm_data_train)
#   - SQL: select variables; filter dataset='perm_historical' and expdeathqx2015vbtwmi_bypol > 0; add attained_age_m = round(issue_age + duration)
#   - session_id = fd884250-f4a9-4cd9-8598-b3d948f9e785; n_rows = 1,901,686
# - TEST
#   - cmd_create_dataset(dataset_name = perm_data_test) with same logic for train_test='TEST'
#   - session_id = 3abb91f4-fcbe-4daa-aa4f-e3434caaf4be; n_rows = 799,632
#
# 3) Variable importance (decision trees, Poisson with offset)
# - Train, set A: attained_age_m, duration, gender, smoker_status, face_amount_band_int
#   - cmd_rpart(...) -> session_id = 2b318def-d83a-4fa4-b203-e1e4dd74ed46
#   - Face amount and attained_age dominated; gender/smoker split only in subtrees
# - Train, set B: attained_age_m, duration, age_basis, observation_year, preferred_indicator
#   - cmd_rpart(...) -> session_id = 61e336da-5915-4808-bcbc-9ff5f4d8fd4c
#   - age_basis (ANB vs ALB), duration, observation_year meaningful; preferred_indicator matters in younger ranges
#
# 4) GLM via glmnet (Poisson)
# - Dataset: perm_data_train
# - x_vars:
#   - Numeric: attained_age_m, duration, face_amount_band_int, observation_year, preferred_indicator
#   - Character (factors): gender, smoker_status, age_basis
# - Design matrix terms:
#   - splines::ns(attained_age_m, knots = c(60, 76, 84), Boundary.knots = c(15, 96))
#   - splines::ns(duration, knots = c(16, 22, 28), Boundary.knots = c(7, 36))
#   - splines::ns(face_amount_band_int, knots = c(3, 5, 7), Boundary.knots = c(1, 11))
#   - gender + smoker_status + age_basis (factor-expanded)
#   - preferred_indicator + observation_year (linear)
# - Factor defaults: gender=MALE, smoker_status=NONSMOKER, age_basis=ANB
# - Numeric clipping: attained_age_m [15,96]; duration [7,36]; face_amount_band_int [1,11]; observation_year [2009,2018]; preferred_indicator [0,1]
# - Lambda selection: 1se
# - cmd_glmnet(...) -> session_id = 5664c210-fa1a-4c17-8b19-244d720de6ff
#   - Train A/E sanity: 1.0000 (within ±3% check)
#   - Internal rpart diagnostic found no further splits (well-calibrated fit at cp=0.001)
#
# 5) Inference
# - Train preds: cmd_run_inference(dataset_in=perm_data_train, dataset_out=perm_data_train_preds)
#   - session_id = 08a2223c-74f0-4e92-85ec-6657460bd3c6
# - Test preds: cmd_run_inference(dataset_in=perm_data_test, dataset_out=perm_data_test_preds)
#   - session_id = cea8a877-de94-4c8c-b59a-81f548c64c87
#
# 6) Post-fit evaluation (Poisson trees on predictions)
# - Train eval: cmd_rpart on perm_data_train_preds with x_vars = attained_age_m, duration, gender, smoker_status, face_amount_band_int; offset=MODEL_PRED
#   - session_id = 3b1b1fdf-b67e-420f-a847-eb82b2b36c95
#   - Overall A/E ~ 1.000; segments mostly within ~±10%; low attained_age (<20.5) under by ~30% (small volume)
# - Test eval: same setup on perm_data_test_preds
#   - session_id = bb8a26c2-8b75-4ce8-9976-da313b46cd18
#   - Overall A/E = 1.014
#   - Notable segments:
#     - Attained_age_m < 51.5 AND face_amount_band_int < 2.5: A/E ~ 1.40
#     - Very old (≥83.5) and higher face bands (≥3.5): A/E ~ 1.18
#     - Ages 52–74.5 and higher face bands show underprediction (A/E ~0.85–0.95)
#
# Model rationale
# - Core risk drivers at late durations are attained age and size (face_amount_band_int); both show clear non-linear patterns, so natural splines with knot locations guided by rpart splits and empirical quantiles were used.
# - Duration retained due to residual selectiveness even at late durations, with knot locations around 16, 22, and 28 aligning to tree splits and quartiles.
# - Categorical effects (smoker, gender, age_basis) included for actuarial consistency; observation_year captures period effects; preferred_indicator adds a preferred/non-preferred distinction without collinearity with preferred_class levels.
# - Offset is policy-expected deaths on 2015 VBT WMI; model predicts deviations around VBT, anchoring to a credible baseline.
#
# Data quality issues and adjustments
# - No rows with offset <= 0 after filtering.
# - Age arithmetic inconsistencies (attained_age vs issue_age + duration) consistent with ALB/ANB and rounding; standardized to attained_age_m = round(issue_age + duration) for modeling.
# - Categorical completeness: no NULLs; preferred_class has “NA” as a literal level; retained as-is (not used directly in the GLM to avoid redundancy with preferred_indicator).
#
# Results summary
# - Training A/E: 1.000
# - Testing A/E: 1.014
# - Calibration is strong overall; some residual misfit in:
#   - Small face bands at younger attained ages (<52): overprediction (A/E ~1.40)
#   - Very old ages (≥83.5) and higher face bands: modest overprediction (A/E ~1.18)
# - Potential refinements (next iteration): add interaction terms for attained_age_m × face_amount_band_int and smoker_status × attained_age_m; consider an extra inner knot around attained_age_m ≈ 83–85 and a face band knot near 8–9 to improve high-age/high-face calibration. Current fit passed training sanity and tested well.
#
# Final session_id
# - bb8a26c2-8b75-4ce8-9976-da313b46cd18 (final evaluation step)

# %%
! cp -r /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/ /home/mike/workspace/soa-ilec/mcp_agent_work_model_1
! rm -rf /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/session_*
! rm -f /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/*

# %% [markdown]
# #### Model #2

# %%
set_context_window_size(10)

# %%
modeling_prompt = """The goal is to create a model to predict late-duration whole life (perm_historical) mortality on the ILEC_DATA. Use Number_Of_Deaths as the target (y_var) and Expected_Death_QX2015VBT_by_Policy as the offset (offset_var)"""\
    """The ILEC_DATA can be queried with sql_query() and its schema is available with sql_schema(), perform exploratory data analysis with these methods."""\
    """The ILEC_DATA has data quality problems, so identify and fix when possible. Remove any rows where Expected_Death_QX2015VBT_by_Policy <= 0."""\
    """To build a model, first call cmd_init(), this returns a session_id that should be passed as the first argument to the next cmd_*() call."""\
    """Each call to a cmd_*() method returns a session_id, which is an immutable workspace associated with any changes in state resulting from that method call, e.g. creation of datasets, models, and inference data."""\
    """This allows backtracking to previous states in modeling."""\
    """After calling cmd_init(), create two datasets called "perm_data_train" and "perm_data_test" with calls to cmd_create_dataset(), apply fixes for any data quality problems."""\
    """We are using Observation_Year for the test-train split. perm_data_train should be Observation_Years < 2016, and perm_data_test should be Observation_Years >= 2016."""\
    """Next, determine variable importance call(s) to cmd_rpart(), use both actuarial soundness and predictive power as criteria for selecting variables."""\
    """Then, call cmd_glmnet() to build a model, any splines specified in design_matrix_vars must have both `Boundary.knots` and `knots` fully specified, do not use the `df` argument."""\
    """Use the decision tree returned by cmd_glmnet() to refine the design matrix, particularly inner knot locations."""\
    """Then run inference using cmd_run_inference() on both perm_data_train and perm_data_test to create perm_data_*_preds.  Run a decision tree on the results using cmd_rpart() and evaluate the final results."""\
    """Back-track if necessary.  Provide a final summary with a short description of the model rationale, any data quality problems and adjustments, and the session_id associated with the final step in the modeling process."""


print(prompt_ilec_data(modeling_prompt))
# Out:
# Running request...
# Plan and actions taken
# - Explored ILEC_DATA, confirmed target and offset fields, checked data quality, and subset to late-duration whole life: dataset = 'perm_historical'.
# - Built train/test datasets by Observation_Year, removed any rows with non-positive offsets (none existed in this dataset), standardized categorical levels.
# - Assessed variable importance with a Poisson decision tree (offset exposure), selected variables balancing actuarial sense and predictive power.
# - Fit a Poisson GLM via glmnet using natural splines with explicit boundary.knots and knots, then refined spline knot locations based on the model’s post-fit tree diagnostics (back-tracked to re-fit).
# - Scored both train and test sets and evaluated with decision trees on the prediction datasets.
#
# Key EDA highlights
# - Schema mapping
#   - y_var: number_of_deaths
#   - offset_var: expdeathqx2015vbtwmi_bypol (Expected_Death_QX2015VBT_by_Policy)
#   - Split variable: observation_year
#   - Other fields used: gender, smoker_status, issue_age, duration, face_amount_band_int, preferred_indicator
# - Dataset partitioning
#   - dataset distinct: perm_historical only
#   - observation_year range: 2009–2018
#   - duration range: 5–38 (late-duration dataset)
# - Data quality checks
#   - expdeathqx2015vbtwmi_bypol <= 0: 0 rows
#   - number_of_deaths < 0: 0 rows
#   - policies_exposed, amount_exposed non-positive: 0 rows
#   - attained_age ≈ issue_age + duration: 0 mismatches beyond 1 year tolerance
#   - Gender levels: MALE/FEMALE; Smoker levels: SMOKER/NONSMOKER
# - Actioned data cleaning
#   - Kept only dataset='perm_historical'
#   - Enforced offset > 0
#   - Filtered to gender in ('MALE','FEMALE') and smoker_status in ('SMOKER','NONSMOKER')
#
# Datasets created
# - perm_data_train: Observation_Year < 2016, n = 1,901,686
# - perm_data_test: Observation_Year >= 2016, n = 799,632
#
# Variable importance (rpart on train, offset=Expected)
# - Strongest splits: face_amount_band_int, issue_age; secondary: duration
# - gender/smoker_status weaker overall, but gender shows interaction at older ages/high face bands
# - Example initial tree (train): splits at face_amount_band_int around 3.5–4.5 and issue_age around ~52; duration around ~23.5 at younger ages
#
# Modeling
# - Initial glmnet model
#   - x_vars: gender, smoker_status, issue_age, duration, face_amount_band_int, preferred_indicator
#   - design_matrix_vars:
#     - splines::ns(issue_age, knots = c(40, 52, 65), Boundary.knots = c(18, 90))
#     - splines::ns(duration, knots = c(10, 24, 30), Boundary.knots = c(5, 38))
#     - splines::ns(face_amount_band_int, knots = c(2, 4, 6, 8), Boundary.knots = c(1, 11))
#     - gender, smoker_status, preferred_indicator
#   - factor reference levels: list("gender"="MALE", "smoker_status"="NONSMOKER")
#   - numeric clipping: list("issue_age"=c(18,90), "duration"=c(5,35), "face_amount_band_int"=c(1,11))
#   - lambda_strat: 1se
#   - Result: ae_train ~ 1.0000; post-fit rpart highlighted issue_age (~25.5, 43.5) and face_amount
#
# - Refined glmnet model (back-tracked and re-fit using rpart splits to guide knots)
#   - x_vars: gender, smoker_status, issue_age, duration, face_amount_band_int, preferred_indicator
#   - design_matrix_vars:
#     - splines::ns(issue_age, knots = c(25, 44, 65), Boundary.knots = c(18, 90))
#     - splines::ns(duration, knots = c(24), Boundary.knots = c(5, 38))
#     - splines::ns(face_amount_band_int, knots = c(2, 4), Boundary.knots = c(1, 11))
#     - gender, smoker_status, preferred_indicator
#   - Same factor defaults and numeric clipping; lambda_strat = 1se
#   - Result: ae_train ~ 1.0000
#   - Post-fit diagnostics (tree on the training inference view): splits at face_amount_band_int (~3.5–5.5), issue_age (~55–58); gender effect visible at older ages/high bands
#
# Inference and evaluation
# - Scored both datasets:
#   - perm_data_train_preds created with MODEL_PRED
#   - perm_data_test_preds created with MODEL_PRED
# - Decision-tree evaluation on predictions (offset = MODEL_PRED, y = number_of_deaths):
#   - Train preds tree root yval ~ 1.000 (confirms AE ≈ 100%)
#   - Test preds tree root yval ~ 1.030 (AE ≈ 103% overall), with residual lift concentrated at older issue ages and higher face bands; structure consistent with training diagnostics
#
# Selected final model rationale
# - Actuarial priors: At late durations, class effects shrink; shape by issue age and policy size dominate. The model reflects this via flexible splines on issue_age and face_amount_band_int, modest duration nonlinearity, and categorical effects for gender/smoker_status that glmnet can retain or shrink as warranted.
# - Predictive performance: AE_train ~ 100%; AE_test ~ 103% with interpretable residual pattern (older ages, high face amounts), suitable for post-level adjustment or an experience factor if desired.
#
# Final artifacts
# - Training dataset: perm_data_train.parquet
# - Test dataset: perm_data_test.parquet
# - Scored outputs: perm_data_train_preds.parquet, perm_data_test_preds.parquet (MODEL_PRED column)
# - Final session_id: 27c8818a-65df-4e1a-a5db-ea570b51a66e
#
# Notes and next steps
# - If you prefer tighter AE on test, consider:
#   - Adding a mild observation_year trend spline or a by-year factor (guarded to avoid overfitting)
#   - A small interaction between issue_age and face_amount_band_int (e.g., tensor or grouped interaction terms)
# - The current model is balanced for stability and interpretability on late-duration whole life; residuals suggest targeted refinement mostly at high bands/older ages.

# %%
! cp -r /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/ /home/mike/workspace/soa-ilec/mcp_agent_work_model_2
! rm -rf /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/session_*
! rm -f /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/*

# %% [markdown]
# #### Model #3

# %%
set_context_window_size(10)

# %%
modeling_prompt = """The goal is to create a model to predict late-duration whole life (perm_historical) mortality on the ILEC_DATA. Use Number_Of_Deaths as the target (y_var) and Expected_Death_QX2015VBT_by_Policy as the offset (offset_var)"""\
    """The ILEC_DATA can be queried with sql_query() and its schema is available with sql_schema(), perform exploratory data analysis with these methods."""\
    """The ILEC_DATA has data quality problems, so identify and fix when possible. Remove any rows where Expected_Death_QX2015VBT_by_Policy <= 0."""\
    """To build a model, first call cmd_init(), this returns a session_id that should be passed as the first argument to the next cmd_*() call."""\
    """Each call to a cmd_*() method returns a session_id, which is an immutable workspace associated with any changes in state resulting from that method call, e.g. creation of datasets, models, and inference data."""\
    """This allows backtracking to previous states in modeling."""\
    """After calling cmd_init(), create two datasets called "perm_data_train" and "perm_data_test" with calls to cmd_create_dataset(), apply fixes for any data quality problems."""\
    """We are using Observation_Year for the test-train split. perm_data_train should be Observation_Years < 2016, and perm_data_test should be Observation_Years >= 2016."""\
    """Next, determine variable importance call(s) to cmd_rpart(), use both actuarial soundness and predictive power as criteria for selecting variables."""\
    """Then, call cmd_glmnet() to build a model, any splines specified in design_matrix_vars must have both `Boundary.knots` and `knots` fully specified, do not use the `df` argument."""\
    """Use the decision tree returned by cmd_glmnet() to refine the design matrix, particularly inner knot locations."""\
    """Then run inference using cmd_run_inference() on both perm_data_train and perm_data_test to create perm_data_*_preds.  Run a decision tree on the results using cmd_rpart() and evaluate the final results."""\
    """Back-track if necessary using information about the errors learned from running inference on the testing set."""\
    """Provide a final summary with a short description of the model rationale, any data quality problems and adjustments, and the session_id associated with the final step in the modeling process."""


print(prompt_ilec_data(modeling_prompt))
# Out:
# Running request...
# Plan
# - Explore ILEC_DATA structure and quality for perm_historical.
# - Create training and test datasets with quality filters and late-duration restriction.
# - Screen variable importance with poisson decision trees.
# - Fit a Poisson GLM via glmnet with offset = Expected_Death_QX2015VBT_by_Policy.
# - Use natural spline terms with explicit inner and boundary knots.
# - Run inference on train and test, then tree-based calibration checks (A/E by segments).
# - Back-track and refine if errors arise.
#
# Key EDA findings
# - Table: perm_historical only, 2,701,318 rows, observation_year 2009–2018.
# - No rows with expdeathqx2015vbtwmi_bypol <= 0 (n_bad_expdeath=0).
# - Duration: min 5, max 38, avg ~21.7; for obs_year<2016 and duration>=10: min 10, max 35, p10=13, p50=21, p90=29.
# - Attained age (train, obs_year<2016, dur>=10): min 9, max 113, p10=32, p50=60, p90=85.
# - No nulls in key fields used (number_of_deaths, policies_exposed, amount_exposed). qx has nulls (not used).
# - Reasonableness: Yearly A/E (Deaths / Expected) ranges about 1.09–1.14 pre-2016 and ~1.09–1.13 post-2016.
#
# Data quality actions
# - Enforced offset > 0 even though none removed.
# - Restricted to late duration: duration >= 10 to meet study intent.
# - Kept string “NA” categories (preferred_class, number_of_preferred_classes) as explicit levels rather than treating as missing.
# - Verified no negative or logically impossible ages; attained_age ≥ issue_age holds.
#
# Dataset creation
# - Session initialization: 50a59551-a5e0-465e-bc35-cafacf49907b
# - perm_data_train (obs_year < 2016, dur ≥ 10, offset > 0): 1,805,377 rows
# - perm_data_test (obs_year ≥ 2016, dur ≥ 10, offset > 0): 799,632 rows
#
# Variable screening with poisson trees (offset = expdeath…)
# - Categorical set (gender, smoker_status, preferred_class, number_of_preferred_classes, face_amount_band_int): face_amount_band_int strongest; preferred_class and gender meaningful.
# - Mixed set (duration, attained_age, observation_year, preferred_indicator, face_amount_band_int): face_amount_band_int and attained_age dominate; observation_year/duration secondary.
# - Mixed set (gender, smoker_status, duration, attained_age, observation_year): attained_age and duration lead; smoker_status and gender add lift.
#
# Final glmnet model
# - Backtracked design to maintain stability in streaming inference. Replaced factor(observation_year) with spline(year) to avoid “contrasts” errors in chunks with single-level factors.
# - x_vars:
#   - Character: gender, smoker_status, preferred_class, number_of_preferred_classes
#   - Numeric: preferred_indicator, face_amount_band_int, duration, attained_age, observation_year
# - design_matrix_vars:
#   - splines::ns(attained_age, knots = c(32,60,85), Boundary.knots = c(9,113))
#   - splines::ns(duration, knots = c(13,21,29), Boundary.knots = c(10,35))
#   - splines::ns(observation_year, knots = c(2011,2013), Boundary.knots = c(2009,2015))
#   - gender + smoker_status + preferred_class + number_of_preferred_classes
#   - preferred_indicator + face_amount_band_int
# - factor_vars_levels for character predictors:
#   - gender = MALE
#   - smoker_status = NONSMOKER
#   - preferred_class = NA
#   - number_of_preferred_classes = NA
# - num_var_clip:
#   - duration = [10, 35]
#   - attained_age = [9, 113]
#   - preferred_indicator = [0, 1]
# - Offset: expdeathqx2015vbtwmi_bypol
# - Target: number_of_deaths
# - Lambda strategy: 1se
# - Training A/E sanity check: 1.00 (within tolerance)
#
# Inference and calibration
# - Inference outputs:
#   - perm_data_train_preds created with MODEL_PRED
#   - perm_data_test_preds created with MODEL_PRED
# - Post-inference calibration trees (offset = MODEL_PRED, y = number_of_deaths), x_vars = attained_age, duration, face_amount_band_int, smoker_status, gender:
#   - Train: Root A/E ~ 1.000; small pockets of misfit mainly at very high face_amount_band_int and high attained ages (e.g., band ≥ 7.5 and attained_age ≥ ~75 had A/E ~1.45).
#   - Test: Root A/E ~ 1.015; under-prediction at very young attained ages (< ~36.5) and some older/high-face-amount cells; otherwise close to 1 with modest deviations by duration and age.
#
# Operational notes and backtracking
# - Initial design used factor(observation_year), which failed in chunked inference due to single-level factor contrasts. Backtracked to pre-glmnet session and replaced with spline on observation_year; inference succeeded on both train and test.
#
# Model rationale
# - Use a Poisson GLM with exposure offset set to expected deaths (2015 VBT WMI by policy) to model residual mortality patterns (A/E).
# - Actuarially grounded predictors:
#   - Age/duration shapes via splines to capture slope mismatches vs VBT.
#   - Smoker, gender, and preferred segmentation for residual selection effects.
#   - Face amount band to capture underwriting/anti-selection and socio-economic effects.
#   - Calendar-year spline for secular mortality trend and data vintage effects.
# - Spline knots chosen from training percentiles to ensure stable, data-driven flexibility with explicit Boundary.knots and inner knots, as required.
#
# Final outputs and where we ended
# - Datasets: perm_data_train, perm_data_test, perm_data_train_preds, perm_data_test_preds
# - Overall test A/E ≈ 1.015; segment-level A/E largely close to 1 with understandable deviations in extreme age/face-amount cells.
# - Final session_id: a47cc7d4-eaba-4184-84dd-21a8c53da373
#
# If you want, I can:
# - Produce year-by-year and segment A/E summaries from perm_data_test_preds.
# - Iterate knots or add limited interactions (e.g., smoker_status with duration or face_amount_band_int) if you want to further tighten specific segments.

# %%
! cp -r /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/ /home/mike/workspace/soa-ilec/mcp_agent_work_model_3
! rm -rf /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/session_*
! rm -f /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/*

# %% [markdown]
# ## Model #4

# %%
set_context_window_size(10)

# %%
modeling_prompt = """The goal is to create a model to predict late-duration whole life (perm_historical) mortality on the ILEC_DATA. Use Number_Of_Deaths as the target (y_var) and Expected_Death_QX2015VBT_by_Policy as the offset (offset_var)"""\
    """The ILEC_DATA can be queried with sql_query() and its schema is available with sql_schema(), perform exploratory data analysis with these methods."""\
    """The ILEC_DATA has data quality problems, so identify and fix when possible. Remove any rows where Expected_Death_QX2015VBT_by_Policy <= 0."""\
    """To build a model, first call cmd_init(), this returns a session_id that should be passed as the first argument to the next cmd_*() call."""\
    """Each call to a cmd_*() method returns a session_id, which is an immutable workspace associated with any changes in state resulting from that method call, e.g. creation of datasets, models, and inference data."""\
    """This allows backtracking to previous states in modeling."""\
    """After calling cmd_init(), create two datasets called "perm_data_train" and "perm_data_test" with calls to cmd_create_dataset(), apply fixes for any data quality problems."""\
    """We are using Observation_Year for the test-train split. perm_data_train should be Observation_Years < 2016, and perm_data_test should be Observation_Years >= 2016."""\
    """Next, determine variable importance call(s) to cmd_rpart(), use both actuarial soundness and predictive power as criteria for selecting variables."""\
    """Then, call cmd_glmnet() to build a model, any splines specified in design_matrix_vars must have both `Boundary.knots` and `knots` fully specified, do not use the `df` argument."""\
    """Valid choices of lambda_strat are: 1se, AIC, BIC. Do not include numeric variables in factor_var_levels."""\
    """If you wish to use a numeric variable in factor_var_levels, cast it as a VARCHAR in the dataset creation step cmd_create_dataset()."""\
    """Use the decision tree returned by cmd_glmnet() to refine the design matrix, particularly inner knot locations."""\
    """Then run inference using cmd_run_inference() on both perm_data_train and perm_data_test to create perm_data_*_preds.  Run a decision tree on the results using cmd_rpart() and evaluate the final results."""\
    """Back-track if necessary using information about the errors learned from running inference on the testing set."""\
    """Provide a final summary with a short description of the model rationale, any data quality problems and adjustments, and the session_id associated with the final step in the modeling process."""

print(prompt_ilec_data(modeling_prompt))
# Out:
# Running request...
# Plan and progress
# - Objective: Predict late-duration whole life (perm_historical) mortality with a Poisson GLMNET using Number_Of_Deaths as y and Expected_Death_QX2015VBT_by_Policy as exposure/offset.
# - Data: ILEC_DATA filtered to dataset='perm_historical', split by Observation_Year (<2016 train, >=2016 test), and remove any rows with Expected_Death_QX2015VBT_by_Policy <= 0.
#
# Key exploratory checks
# - Rows by dataset: perm_historical only; n=2,701,318; Observation_Year in [2009, 2018], Duration in [5, 38].
# - Offset quality: expdeathqx2015vbtwmi_bypol has no zeros or nulls.
# - Other quality:
#   - qx has ~121,506 nulls; not used as a feature.
#   - Numeric exposures are positive: policies_exposed min > 0, amount_exposed min > 0.
#   - Categorical levels within limits: gender(2), smoker_status(2), age_basis(2), face_amount_band(11), preferred_class(4), number_of_preferred_classes(3). Some “NA” present as a string level.
# - Ranges: issue_age [0,98], attained_age [4,113], duration [5,38], face_amount_band_int [1,11].
#
# What I built
# 1) Initialize
# - Session: 4ae73ce1-8e09-4af2-88f7-ebc6437c183c
#
# 2) Create modeling datasets (with explicit aliases for target/offset)
# - perm_data_train (Observation_Year < 2016) n=1,901,686 rows
# - perm_data_test (Observation_Year >= 2016) n=799,632 rows
# - Both datasets contain:
#   - observation_year, gender, smoker_status, age_basis, face_amount_band_int, issue_age, duration, attained_age, preferred_indicator, preferred_class, number_of_preferred_classes
#   - Number_Of_Deaths as Number_Of_Deaths
#   - expdeathqx2015vbtwmi_bypol as Expected_Death_QX2015VBT_by_Policy
# - Data filter/fix applied: dataset='perm_historical' and Expected_Death_QX2015VBT_by_Policy > 0.
#
# 3) Variable importance via Poisson decision trees (offset = Expected_Death_QX2015VBT_by_Policy)
# - Strongest predictors: face_amount_band_int and attained_age.
# - Secondary signals: smoker_status, gender; duration sometimes shows up; observation_year/preferred_indicator did not add much.
# - Example splits:
#   - face_amount_band_int thresholds around 3.5, 4.5, 7.5
#   - attained_age splits around 58.5, 75.5, 79.5, 84.5
#
# 4) GLMNET model (Poisson with offset)
# - Training dataset: perm_data_train
# - x_vars:
#   - attained_age, duration, face_amount_band_int, gender, smoker_status, issue_age, observation_year, preferred_indicator, age_basis, preferred_class, number_of_preferred_classes
# - Design matrix (no intercept):
#   - splines::ns(attained_age, knots=c(60,75,85), Boundary.knots=c(25,110))
#   - splines::ns(duration, knots=c(10,18,27), Boundary.knots=c(5,38))
#   - face_amount_band_int, I(pmax(face_amount_band_int - 4, 0))
#   - gender, smoker_status, gender:smoker_status (interaction)
#   - issue_age, observation_year, preferred_indicator
#   - age_basis, preferred_class, number_of_preferred_classes
# - Factor baselines:
#   - gender=MALE, smoker_status=NONSMOKER, age_basis=ANB, preferred_class=NA, number_of_preferred_classes=NA
# - Numeric clipping (to stabilize splines):
#   - attained_age [25,110], duration [5,38], face_amount_band_int [1,11], issue_age [15,90], observation_year [2009,2018], preferred_indicator [0,1]
# - Lambda selection: 1se
# - Training A/E sanity check: passed; AE_train ≈ 1.0000
#
# 5) Inference and evaluation (first fit)
# - Predicted:
#   - perm_data_train → perm_data_train_preds
#   - perm_data_test → perm_data_test_preds
# - rpart on predictions with offset=MODEL_PRED:
#   - Train: overall calibration ~1.00; notable segments:
#     - attained_age < 19.5: A/E ≈ 0.68 (under-predicted expected)
#     - high face_amount_band_int ≥ 7.5 and older ages: A/E up to ~1.35
#   - Test: overall A/E ≈ 1.015; patterns:
#     - attained_age < 37.5: A/E ≈ 1.30 (actual higher than model)
#     - Younger/mid ages with higher face amounts/duration show under/over in expected ways
#
# 6) Refinement using test tree insight
# - The test tree flagged a young attained_age bucket (<~37.5) with A/E ~1.30; I added an inner knot at 35 to the attained_age spline.
# - Refit GLMNET with attained_age knots c(35,60,75,85) (same other terms; 1se lambda).
# - Re-ran inference:
#   - perm_data_train → perm_data_train_preds_v2
#   - perm_data_test → perm_data_test_preds_v2
# - Re-evaluation with rpart (offset=MODEL_PRED):
#   - Train: overall at root remains ~1.00; attained_age < 19.5 improved from ~0.68 to ~0.73.
#   - Test: root A/E ≈ 1.015 (similar); attained_age < 37.5 now A/E ≈ 1.322 (little change overall); other patterns stable and acceptable.
#
# Final model specification
# - Response: Number_Of_Deaths
# - Offset: Expected_Death_QX2015VBT_by_Policy
# - Link/family: Poisson log-link with exposure offset
# - Design matrix terms:
#   - splines::ns(attained_age, knots=c(35,60,75,85), Boundary.knots=c(25,110))
#   - splines::ns(duration, knots=c(10,18,27), Boundary.knots=c(5,38))
#   - face_amount_band_int + hinge I(pmax(face_amount_band_int - 4, 0))
#   - gender + smoker_status + gender:smoker_status
#   - issue_age, observation_year, preferred_indicator
#   - age_basis, preferred_class, number_of_preferred_classes
# - Lambda strategy: 1se
# - Numeric clipping during preprocessing: attained_age [25,110], duration [5,38], face_amount_band_int [1,11], issue_age [15,90], observation_year [2009,2018], preferred_indicator [0,1]
# - Factor baselines: gender=MALE, smoker_status=NONSMOKER, age_basis=ANB, preferred_class=NA, number_of_preferred_classes=NA
#
# Results summary
# - Training A/E ≈ 1.00 by construction; segment-level tree residuals are modest, with under-prediction at very young attained ages improved slightly after adding the 35-year knot.
# - Test A/E ≈ 1.015 overall; segment-level residuals are reasonable:
#   - Slight under-prediction at younger ages (<~37.5).
#   - Some over-prediction for high face amount bands at very old ages.
# - Variable importance: face_amount_band_int and attained_age dominate; smoker_status and gender provide consistent refinements; duration helps split calibration in select mid-age/high-band regions.
#
# Data quality issues and how they were handled
# - Enforced Expected_Death_QX2015VBT_by_Policy > 0 (none removed, but guard applied).
# - qx had many nulls; excluded from modeling.
# - Preferred fields contain “NA” as a string; treated as valid factor levels.
# - Numeric extremes handled via clipping in preprocessing to stabilize splines.
# - No negative or zero exposures detected in policies_exposed and amount_exposed; no further action required.
#
# Artifacts created
# - perm_data_train.parquet and perm_data_test.parquet
# - perm_data_train_preds_v2.parquet and perm_data_test_preds_v2.parquet (contain MODEL_PRED)
#
# Session IDs (chronological key points)
# - cmd_init: 4ae73ce1-8e09-4af2-88f7-ebc6437c183c
# - perm_data_train created: 84977dc5-857a-4a46-906e-48b393a8380c
# - perm_data_test created: 5c04ac33-851e-4552-af81-eb10c4338b71
# - First GLMNET fit: 798c2d9e-6076-4e5d-8fac-91ccf2f33345
# - Refined GLMNET (final model): 0081ac3f-4934-4a47-b4ca-7038d7d3636f
# - Final evaluation step session_id: 6b79f3b0-2c10-436a-83d8-1aad2452c86f
#
# Next steps if we want further refinement
# - Add another attained_age inner knot around 30 to further address A/E > 1.3 for <~37.5, or introduce a piecewise term like I(pmax(35 - attained_age, 0)) to allow a separate young-age slope.
# - Consider a banded treatment of face_amount_band_int (factor encoding) if you prefer non-monotone effects across bands, achieved by casting to VARCHAR at dataset creation if we need a factor baseline.

# %%
! cp -r /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/ /home/mike/workspace/soa-ilec/mcp_agent_work_model_4
! rm -rf /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/session_*
! rm -f /home/mike/workspace/soa-ilec/soa-ilec/mcp_agent_work/*
